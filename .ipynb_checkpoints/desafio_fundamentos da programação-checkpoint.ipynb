# %% [markdown]
# # KICK OFF DO PROJETO!

# %% [markdown]
# ## Contexto do Problema de Negócio

# %% [markdown]
# A Xtreme Groovy Bikes Sales é uma empresa de revenda de motocicletas. Seu modelo de nogócio é revender motocicletas usadas. Com a crescente do valor dos veículos usados, a XGB Sales, como é conhecida, deseja expandir os seus negócios. Você foi contratado como cientista de dados pela empresa XGB Sales para ajudá-los a encotrar as melhores motocicletas para revenda.
#
# Para isso, o CEO da empresa fez um estudo de mercado lhe entregou uma base de dados, obtida através desse estudo, para que você consiga auxiliá-lo a encontrar as melhores motocicletas para revenda, aumentando assim o lucro da empresa.
#
# Além disso, o CEO lhe fez algumas perguntas a cerca da base de dados que a empresa possui.
# Lembrando que o contexto, pessoas e perguntas são completamente fictícios e existem somente na minha imaginação.

# %% [markdown]
# ## O Desafio

# %% [markdown]
# A empresa XGB Sales lhe contratou como cientista de dados pois ela deseja aumentar o seu lucro comprando e revendendo as melhores motos disponíveis dentro da base de dados que a empresa adquiriu através de um estudo de mercado.
#
# Dessa forma, o CEO da XGB Sales lhe fez as seguintes perguntas:
#
# 1. Quantas motos temos dentro do Dataset?
# 2. Qual é o ano da moto mais antiga da base de dados?
# 3. Qual é o ano da moto mais nova da base de dados?
# 4. Qual é o valor da moto mais cara da base de dados?
# 5. Qual é o valor do hodômotro da moto com a maior quilometragem?
# 6. Qual é o valor do hodômotro da moto com a menor quiilometragem?
# 7. Das motocicletas que estão sendo expostas dentro de um Show Room, qual é o maior valor registrado na base de dados?
# 8. Das motocicletas que estão sendo expostas dentro de um Show Room, qual é o menor valor registrado na base de dados?
# 9. Quantas motocicletas estão sendo vendidades pelos seus donos e quantas estão sendo vendidas por outros revendedores?
# 10. Qual é a média de valores das motos na base de dados?
# 11. Qual é a média de ano das motos cadastradas dentro da base de dados?
# 12. Qual é a média de quilometragem das motos cadastradas dentro da base de dados?
# 13. Existem quantas motos dentro da base de dados que são motos de um único dono?
# 14. As motos com menor quilometragem são as motos mais baratas do Dataset?

# %% [markdown]
# ##  A Base de Dados

# %% [markdown]
# O conjunto de dados que representam o contexto está disponível na plataforma do Kaggle. O link para acesso aos dados:
#
# [Motorcycle Dataset](https://www.kaggle.com/datasets/nehalbirla/motorcycle-dataset)

# %% [markdown]
# ## Como Solucionar Esse Desafio

# %% [markdown]
# Aqui vão algumas dicas para você começar a resolver esse problema:
#
# * **Tenha calma e não tenha medo:** Crie suposições e faça testes, dando um passo de cada vez para, a cada novo passo, estar mais próximo da resposta.
#
# * **Responda as perguntas antes de Codificar:** Como você faria, se não tivesse que programar, para responder as perguntas feitas? Pensando antes em como responder, facilitará no momento de codificar o algoritmo para achar a resposta, porque isso faz parte do planejamento da solução!
#
# * **Tenha Paciência e Resiliência:** Criar soluções e, principalmente, pensar e planejá-las leva tempo. Assuma uma postura resiliente e não desista! Afinal, você quer se tornar um Cientista de Dados, ganhar ótimos salários e trabalhar em ótimas empresas, certo?
#
# * **A Comunidade:** Caso você tenha tentado várias estratégias e não tenha chegado a uma solução ou não tenha avançado, peça ajuda dentro da Comunidade de DS! Estamos todos para nos ajudar nessa jornada que é a Ciência de Dados.
#
# * **Crie Visualizações:** Caso a tabela gerada com as informações não seja de fácil entendimento, gere um gráfico/visualização para facilitar a compreensão do CEO.
#
# * **Estudem os dados antes de Qualquer coisa:** Façam a leitura do arquivo e estudem o que cada coluna representa. Criem a dicionário explicado cada uma das colunas.

# %% [markdown]
# # 0.0 IMPORTS E FUNÇÕES AUXILIARES

# %% [markdown]
# ## 0.1 Imports

# %%
import math
import re

import pandas  as pd
import numpy   as np
import seaborn as sns
import datetime

from IPython.display import Image
from IPython.core.display import HTML

# %% [markdown]
# ##  0.2 Funções auxiliares

# %%
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [20, 10]
    plt.rcParams['font.size'] = 24
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    sns.set()

# %%
jupyter_settings()
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## 0.3 Loading Data

# %%
data_raw = pd.read_csv('../fund_prog_project/data/csv/bike.csv',low_memory=False)

# %% [markdown]
# # 1.0 Descrição das colunas

# %%
df1 = data_raw.copy()

# Inserindo coluna ID 
df1['id'] =df1.index

# movendo columa ID para primeira posição
first_column = df1.pop("id")
df1.insert(0, 'id',first_column)

# %% [markdown]
# **name**: Modelo/marca da motocicleta
#
# **selling_price**: Preço de venda da motocicleta
#
# **year**: Ano de compra da motocicleta
#
# **seller_type**: refere-se ao tipo de vendedor, individual ou dealer(revendedor)
#
# **owner**: Indica se o atual proprietário da nmotocicleta é o primeiro dono ou não.
#          ('1st owner', '2nd owner', '3rd owner', '4th owner')
#
# **km_driven**: Km rodados pelo veículo atéo momento.
#
# **ex_showroom_price**: Valor de venda do veículo em showroom (motocicletas com NaN nessa coluna não estão em showroom)

# %% [markdown]
# ## 1.1 Data Dimensions

# %%
print(f'Number of Rows:{df1.shape[0]}')
print(f'Number of columns:{df1.shape[1]}')
# Out:
# Number of Rows:1061
# Number of columns:8

# %% [markdown]
# ## 1.2 Data Types

# %%
#convert selling price - int to float
df1['selling_price'] = df1['selling_price'].astype(float)
df1['ex_showroom_price'] = df1['ex_showroom_price'].astype(float)

# %%
df1.dtypes
# Out:
# id                     int64
# name                  object
# selling_price        float64
# year                   int64
# seller_type           object
# owner                 object
# km_driven              int64
# ex_showroom_price    float64
# dtype: object

# %% [markdown]
# ## 1.3 Check NA

# %%
df1.isna().sum()
# Out:
# id                   0
# name                 0
# selling_price        0
# year                 0
# seller_type          0
# owner                0
# km_driven            0
# ex_showroom_price    0
# dtype: int64

# %% [markdown]
# ## 1.4 Fillup NA

# %%
df1['ex_showroom_price'] = df1['ex_showroom_price'].apply( lambda x: 0 if math.isnan(x) else x)

# %%
df1[df1['name'].str.contains('Hero Honda')]
# Out:
#         id                              name  selling_price  year seller_type      owner  km_driven  ex_showroom_price
# 8        8            Hero Honda CBZ extreme        30000.0  2010  Individual  1st owner      32000                0.0
# 16      16                Hero Honda Glamour        25000.0  2006  Individual  1st owner      27000                0.0
# 29      29           Hero Honda Splendor NXG        21000.0  2009  Individual  1st owner      10000                0.0
# 38      38     Hero Honda Passion PRO [2012]        30000.0  2011  Individual  1st owner      42000                0.0
# 55      55           Hero Honda Passion Plus        25000.0  2006  Individual  1st owner      75000                0.0
# 76      76     Hero Honda Karizma ZMR [2010]        50000.0  2010  Individual  1st owner      48000                0.0
# 85      85              Hero Honda CD Deluxe        25000.0  2009  Individual  1st owner      50000                0.0
# 113    113                Hero Honda Glamour        30000.0  2008  Individual  1st owner       7500                0.0
# 115    115           Hero Honda Passion Plus         7500.0  2004  Individual  1st owner     120000                0.0
# 126    126            Hero Honda CBZ extreme        25000.0  2010  Individual  1st owner      40000                0.0
# 135    135            Hero Honda CBZ extreme        20000.0  2007  Individual  1st owner      90000                0.0
# 166    166               Hero Honda Pleasure        23000.0  2010  Individual  1st owner      32000                0.0
# 196    196                   Hero Honda Hunk        56000.0  2015  Individual  1st owner      48000                0.0
# 197    197                   Hero Honda Hunk        58000.0  2015  Individual  1st owner      48000                0.0
# 219    219                Hero Honda Glamour        15000.0  2006  Individual  1st owner      80000                0.0
# 225    225                Hero Honda Passion         9000.0  2002  Individual  2nd owner      66191                0.0
# 256    256          Hero Honda Splendor Plus        15000.0  2005  Individual  1st owner      65000                0.0
# 258    258     Hero Honda Passion PRO [2012]        25000.0  2011  Individual  1st owner      20000                0.0
# 264    264          Hero Honda Splendor Plus        20000.0  2006  Individual  1st owner      23000                0.0
# 283    283            Hero Honda CBZ extreme        42000.0  2010  Individual  1st owner      51000                0.0
# 307    307          Hero Honda Splendor Plus        15000.0  2007  Individual  1st owner      30000                0.0
# 314    314                   Hero Honda Hunk        28000.0  2009  Individual  1st owner      40000                0.0
# 321    321           Hero Honda Splendor PRO        30000.0  2012  Individual  1st owner      22866                0.0
# 333    333          Hero Honda Splendor Plus        12000.0  2005  Individual  1st owner      48000                0.0
# 346    346          Hero Honda Splendor Plus        18000.0  2010  Individual  1st owner      35700                0.0
# 349    349          Hero Honda Splendor Plus        15000.0  2004  Individual  1st owner      14500                0.0
# 363    363                Hero Honda CD100SS        10000.0  1997  Individual  1st owner     646000                0.0
# 410    410          Hero Honda Splendor Plus        28000.0  2008  Individual  1st owner      70889                0.0
# 422    422               Hero Honda Splendor        10000.0  2000  Individual  1st owner      61000                0.0
# 428    428     Hero Honda Karizma ZMR [2010]        45000.0  2012  Individual  3rd owner      44000                0.0
# 431    431              Hero Honda CD Deluxe        14700.0  2005  Individual  2nd owner      30000                0.0
# 435    435                Hero Honda Glamour        19000.0  2012  Individual  1st owner      32000                0.0
# 440    440          Hero Honda Splendor Plus        40000.0  2007  Individual  1st owner      40000                0.0
# 472    472              Hero Honda CD Deluxe        24700.0  2012  Individual  2nd owner      40000                0.0
# 474    474     Hero Honda Passion PRO [2012]        12000.0  2012  Individual  1st owner      90000                0.0
# 478    478                  Hero Honda CD100        15000.0  1999      Dealer  2nd owner      10000                0.0
# 482    482           Hero Honda Passion Plus        40000.0  2018  Individual  1st owner      29000                0.0
# 485    485                  Hero Honda CD100        15000.0  2000  Individual  1st owner      50000                0.0
# 521    521               Hero Honda Pleasure        25000.0  2009  Individual  1st owner      50000                0.0
# 525    525              Hero Honda CD Deluxe        25000.0  2010  Individual  1st owner      35000                0.0
# 530    530     Hero Honda Passion PRO [2012]        28000.0  2011  Individual  2nd owner      60000                0.0
# 535    535              Hero Honda CD Deluxe        12000.0  2007  Individual  2nd owner     100000                0.0
# 539    539              Hero Honda CD Deluxe        15000.0  2011  Individual  1st owner      70000                0.0
# 560    560           Hero Honda Passion Plus        18000.0  2007  Individual  2nd owner      50000                0.0
# 561    561     Hero Honda Passion PRO [2012]        28700.0  2012  Individual  2nd owner      49876                0.0
# 564    564                Hero Honda Glamour        21000.0  2010  Individual  1st owner      11000                0.0
# 568    568           Hero Honda Passion Plus        23500.0  2010  Individual  1st owner      60000                0.0
# 571    571                  Hero Honda CD100        15000.0  1998  Individual  1st owner      65000                0.0
# 574    574               Hero Honda Achiever        15000.0  2009  Individual  1st owner      86000                0.0
# 575    575                Hero Honda Karizma        40000.0  2011  Individual  2nd owner     340000                0.0
# 599    599           Hero Honda Street Smart        10000.0  2000  Individual  1st owner      24000                0.0
# 610    610          Hero Honda Splendor Plus        15000.0  2006  Individual  1st owner     100000                0.0
# 612    612          Hero Honda Splendor Plus        17600.0  2006  Individual  1st owner      52000                0.0
# 630    630          Hero Honda Splendor Plus        10000.0  2007  Individual  1st owner      98000                0.0
# 634    634           Hero Honda Passion Plus        20000.0  2006  Individual  1st owner      28000                0.0
# 638    638  Hero Honda Super Splendor [2005]        20000.0  2008  Individual  1st owner      54000                0.0
# 648    648               Hero Honda Splendor        25000.0  2008  Individual  1st owner      38000                0.0
# 659    659                Hero Honda Glamour        35000.0  2012  Individual  1st owner      30000                0.0
# 660    660            Hero Honda CBZ extreme        35000.0  2011  Individual  1st owner      35000                0.0
# 698    698                    Hero Honda CBZ        10000.0  2000  Individual  4th owner      48000                0.0
# 710    710     Hero Honda Passion PRO [2012]        25000.0  2012  Individual  2nd owner      20000                0.0
# 758    758           Hero Honda Passion Plus         8000.0  2003  Individual  1st owner      53500                0.0
# 762    762          Hero Honda Splendor Plus        20000.0  2006  Individual  1st owner      75000                0.0
# 766    766           Hero Honda Splendor NXG        28000.0  2012  Individual  1st owner      49999                0.0
# 778    778          Hero Honda Splendor Plus        20000.0  2005  Individual  1st owner      27370                0.0
# 790    790           Hero Honda Passion Plus        25000.0  2007  Individual  1st owner      70000                0.0
# 795    795               Hero Honda Splendor        10000.0  2006  Individual  1st owner      75000                0.0
# 796    796              Hero Honda CD Deluxe        25000.0  2008  Individual  3rd owner      65000                0.0
# 807    807            Hero Honda CBZ extreme        35000.0  2011  Individual  1st owner      28000                0.0
# 822    822                Hero Honda Glamour        45000.0  2012  Individual  1st owner      75000                0.0
# 853    853            Hero Honda CBZ extreme        25000.0  2007  Individual  1st owner      80000                0.0
# 862    862           Hero Honda Passion Plus        22000.0  2008  Individual  2nd owner      85000                0.0
# 863    863          Hero Honda Splendor Plus        15000.0  2007  Individual  1st owner      70000                0.0
# 901    901           Hero Honda Passion Plus        25000.0  2008      Dealer  2nd owner     100000                0.0
# 903    903          Hero Honda Splendor Plus        20000.0  2004  Individual  2nd owner     127000                0.0
# 905    905          Hero Honda Splendor Plus        20000.0  2010  Individual  2nd owner      30000                0.0
# 920    920                   Hero Honda Hunk        45000.0  2013  Individual  1st owner      40000                0.0
# 925    925          Hero Honda Splendor Plus        25000.0  2012  Individual  1st owner      70000                0.0
# 932    932              Hero Honda CD Deluxe        25500.0  2012  Individual  1st owner      28990                0.0
# 933    933                   Hero Honda Hunk        35000.0  2010  Individual  1st owner      13000                0.0
# 934    934              Hero Honda CD Deluxe        20000.0  2005  Individual  1st owner      15000                0.0
# 939    939            Hero Honda CBZ extreme        30000.0  2011  Individual  3rd owner      70000                0.0
# 945    945                   Hero Honda Hunk        40000.0  2010  Individual  1st owner      41000                0.0
# 952    952                   Hero Honda Hunk        20000.0  2010  Individual  1st owner      17000                0.0
# 958    958            Hero Honda CBZ extreme        40000.0  2009  Individual  1st owner      50000                0.0
# 959    959            Hero Honda CBZ extreme        35000.0  2012  Individual  1st owner      60000                0.0
# 1035  1035            Hero Honda CBZ extreme        38000.0  2013  Individual  1st owner      75000            78700.0
# 1040  1040            Hero Honda Passion Pro        30000.0  2014  Individual  1st owner      60000            51000.0

# %% [markdown]
# ## 1.5 Descriptive Statistical

# %%
num_attributes = df1.select_dtypes(include=['int64','float'])
cat_attributes = df1.select_dtypes(exclude=['int64','float'])

# %% [markdown]
# ### 1.5.1 Numerical Attributes

# %%
# Central Tendency  - Tendência central - Média e mediana
ct1 = pd.DataFrame(num_attributes.apply(np.mean)).T
ct2 = pd.DataFrame(num_attributes.apply(np.median)).T

# Dispersion - Desvio padrão, variância, range, min, max skew, curtose (métricas de análise de dispersão de dados)
d1 = pd.DataFrame(num_attributes.apply(np.std)).T
d2 = pd.DataFrame(num_attributes.apply(min)).T
d3 = pd.DataFrame(num_attributes.apply(max)).T
d4 = pd.DataFrame(num_attributes.apply(lambda x: x.max() - x.min() ) ).T
d5 = pd.DataFrame(num_attributes.apply(lambda x: x.skew() ) ).T
d6 = pd.DataFrame(num_attributes.apply(lambda x: x.kurtosis() ) ).T

#concatenate
num_at = pd.concat([d2, d3, d4, ct1, ct2,d1, d5, d6]).T.reset_index()
num_at.columns=['attributes','min', 'max', 'range', 'mean', 'median','std', 'skew', 'kurtosis']
num_at
# Out:
#           attributes     min       max     range          mean   median           std      skew   kurtosis
# 0                 id     0.0    1060.0    1060.0    530.490548    530.5    306.371487 -0.002385  -1.199935
# 1      selling_price  5000.0  425000.0  420000.0  58365.859168  45000.0  47524.467015  2.466591   9.310578
# 2               year  1988.0    2020.0      32.0   2013.867675   2015.0      4.299676 -1.401390   3.235551
# 3          km_driven   350.0  646000.0  645650.0  33611.515123  25000.0  44633.046503  8.042218  88.006891
# 4  ex_showroom_price     0.0  599000.0  599000.0  50124.891304  52271.0  59453.432917  2.950972  18.957234

# %%
df1.loc[(df1['selling_price'] > 700000 )]
# Out:
#       id                        name  selling_price  year seller_type      owner  km_driven  ex_showroom_price
# 134  134  Harley-Davidson Street Bob       750000.0  2013  Individual  2nd owner      12000          1278000.0
# 295  295             Suzuki GSX S750       760000.0  2019  Individual  1st owner       2800           752020.0

# %%
df1.loc[(df1['km_driven'] > 700000 )]
# Out:
#       id                name  selling_price  year seller_type      owner  km_driven  ex_showroom_price
# 642  642  TVS Apache RTR 160        15000.0  2009  Individual  4th owner     880000                0.0

# %%
df1.loc[(df1['ex_showroom_price'] > 700000 )]
# Out:
#       id                        name  selling_price  year seller_type      owner  km_driven  ex_showroom_price
# 134  134  Harley-Davidson Street Bob       750000.0  2013  Individual  2nd owner      12000          1278000.0
# 295  295             Suzuki GSX S750       760000.0  2019  Individual  1st owner       2800           752020.0

# %%
# removing outliers values from selling_price, km_driven and ex_showroom_price 
# IDs removed: 134, 295, 642

aux = df1.loc[ (df1['id'] != 134 ) & (df1['id'] != 295 ) & (df1['id'] != 642 ), :]


plt.subplot(1,3,1)
sns.boxplot(data=aux,y='selling_price')

plt.subplot(1,3,2)
sns.boxplot(data=aux,y='km_driven')

plt.subplot(1,3,3)
sns.boxplot(data=aux,y='ex_showroom_price')
# Out:
# <AxesSubplot:ylabel='ex_showroom_price'>

# %% [markdown]
# ### 1.5.1 Categorical Attributes

# %%
cat_attributes.head()
# Out:
#                                   name seller_type      owner
# 0            Royal Enfield Classic 350  Individual  1st owner
# 1                            Honda Dio  Individual  1st owner
# 2  Royal Enfield Classic Gunmetal Grey  Individual  1st owner
# 3    Yamaha Fazer FI V 2.0 [2016-2018]  Individual  1st owner
# 4                Yamaha SZ [2013-2014]  Individual  2nd owner

# %%
#veriricando qtd de dados diferente por coluna
cat_attributes.apply(lambda x: x.unique().shape[0])
# Out:
# name           279
# seller_type      2
# owner            4
# dtype: int64

# %%
#removendo 2 motos que estavam com valores acima de 700 mil.Abiaxo do gráfico pode-se saber quais foram as motos removidas 

aux = df1.loc[ (df1['id'] != 134 ) & (df1['id'] != 295 ) & (df1['id'] != 642 ), :]

plt.subplot(1,2,1)
sns.boxplot(x='seller_type',y='selling_price', data=aux)


plt.subplot(1,2,2)
sns.boxplot(x='owner',y='selling_price', data=aux)
# Out:
# <AxesSubplot:xlabel='owner', ylabel='selling_price'>

# %%
#counting how many bikes per num of owner after exclusion of 3 outliers 

df_grouped = df1.loc[ (df1['id'] != 134 ) & (df1['id'] != 295 ) & (df1['id'] != 642 ), :].groupby('owner')

df_grouped = df_grouped.agg(
    avg_price = pd.NamedAgg('selling_price', 'mean'),
    qty = pd.NamedAgg('owner', 'count'),
).sort_values('avg_price', ascending=False).reset_index()

df_grouped
# Out:
#        owner      avg_price  qty
# 0  4th owner  170000.000000    2
# 1  1st owner   59264.442037  923
# 2  3rd owner   55727.272727   11
# 3  2nd owner   49975.401639  122

# %% [markdown]
# # 2.0 Feature Engineering

# %%
df2= df1.copy()

# %%
# applying strip in the name
df2['name'] = df2['name'].str.strip()

# Creating new columns for bikes in show room 
df2['in_showroom'] = df2['ex_showroom_price'].apply(lambda x: "0" if x == 0  else '1')
# Out:
#    id                                 name  selling_price  year seller_type      owner  km_driven  ex_showroom_price in_showroom
# 0   0            Royal Enfield Classic 350       175000.0  2019  Individual  1st owner        350                0.0           0
# 1   1                            Honda Dio        45000.0  2017  Individual  1st owner       5650                0.0           0
# 2   2  Royal Enfield Classic Gunmetal Grey       150000.0  2018  Individual  1st owner      12000           148114.0           1
# 3   3    Yamaha Fazer FI V 2.0 [2016-2018]        65000.0  2015  Individual  1st owner      23000            89643.0           1
# 4   4                Yamaha SZ [2013-2014]        20000.0  2011  Individual  2nd owner      21000                0.0           0

# %%
#remove word owner
df2['owner'] = df2['owner'].str.replace('owner','')

# seller_type
df2['seller_type'] = df2['seller_type'].str.lower()

# %%
df2.sample(5)
# Out:
#       id                    name  selling_price  year seller_type owner  km_driven  ex_showroom_price in_showroom
# 935  935         Honda Activa 3G        40000.0  2016  individual  1st       60000            54605.0           1
# 684  684        Bajaj Pulsar 150        25000.0  2013  individual  2nd       70000                0.0           0
# 771  771    Bajaj Discover 125 M        30000.0  2014  individual  1st       45000            49146.0           1
# 398  398    Honda CB Hornet 160R        56000.0  2017  individual  2nd       13200            87543.0           1
# 21    21  Honda Navi [2016-2017]        26000.0  2016  individual  1st       17450            44389.0           1

# %% [markdown]
# # 3 Respondendo as perguntas do CEO

# %% [markdown]
# ## 3.1 Primeira rodada de perguntas

# %%
df3 = df2.copy()
df3_clean = df2.loc[ (df2['id'] != 134 ) & (df2['id'] != 295 ) & (df2['id'] != 642 ), :] # sem os outliers

# %% [markdown]
# **1. Quantas motos temos dentro do Dataset?**

# %%
# considera full dataset
total_motos = df3['name'].count()
print(f'Atualmente existem {total_motos} disponíveis para venda.')
# Out:
# Atualmente existem 1061 disponíveis para venda.

# %% [markdown]
# **2. Qual é o ano da moto mais antiga da base de dados?**

# %%
#considera full dataset
menor_ano = df3['year'].min()
print(f'A moto mais antiga disponível é de {menor_ano} .')
# Out:
# A moto mais antiga disponível é de 1988 .

# %% [markdown]
# **3. Qual é o ano da moto mais nova da base de dados?**

# %%
# considera full dataset
maior_ano = df3['year'].max()
print(f'A moto mais nova disponível é de {maior_ano} .')
# Out:
# A moto mais nova disponível é de 2020 .

# %% [markdown]
# **4. Qual é o valor da moto mais cara da base de dados?**

# %%
# Considera full dataset
maior_valor = df3['selling_price'].max()
print('A moto mais cara disponível está a venda por R${:0,.2f}'.format(maior_valor))
# Out:
# A moto mais cara disponível está a venda por R$760,000.00

# %% [markdown]
# **5. Qual é o valor do hodômotro da moto com a maior quilometragem?**

# %%
# considera full dataset
maior_km = df3['km_driven'].max()
print(' A moto com maior km tem {:,.1f}'.format(maior_km) +' quilômetros.')

maior_km = df3_clean['km_driven'].max()
print(' A moto com maior km, removendo os itens considerados outliers tem {:,.1f}'.format(maior_km) +' quilômetros.')
# Out:
#  A moto com maior km tem 880,000.0 quilômetros.
#  A moto com maior km, removendo os itens considerados outliers tem 646,000.0 quilômetros.

# %% [markdown]
# **6. Qual é o valor do hodômotro da moto com a menor quiilometragem?**

# %%
# full dataset
menor_km = df3['km_driven'].min()
print(' A moto com menor km tem {:,.1f}'.format(menor_km) +' quilômetros.')
# Out:
#  A moto com menor km tem 350.0 quilômetros.

# %% [markdown]
# **7. Das motocicletas que estão sendo expostas dentro de um Show Room, qual é o maior valor registrado na base de dados?**

# %%
# full dataset
aux = df3[df3['in_showroom']=='1']
maior_valor_sr = df3['selling_price'].max()
print(' A moto mais cara exposta em um showroom custa R${:,.2f}'.format(maior_valor_sr) )

# without outliers
aux = df3_clean[df3_clean['in_showroom']=='1']
maior_valor_sr = df3_clean['selling_price'].max()
print(' A moto mais cara exposta em um showroom, se removermos os outliers, custa R${:,.2f}'.format(maior_valor_sr) )
# Out:
#  A moto mais cara exposta em um showroom custa R$760,000.00
#  A moto mais cara exposta em um showroom, se removermos os outliers, custa R$425,000.00

# %% [markdown]
# **8. Das motocicletas que estão sendo expostas dentro de um Show Room, qual é o menor valor registrado na base de dados?**

# %%
# full dataset
aux = df3[df3['in_showroom']=='1']
menor_valor_sr = df3['selling_price'].min()
menor_valor_sr
print(' A moto mais barata exposta em um showroom custa R${:,.2f}'.format(menor_valor_sr) )
# Out:
#  A moto mais barata exposta em um showroom custa R$5,000.00

# %% [markdown]
# **9. Quantas motocicletas estão sendo vendidades pelos seus donos e quantas estão sendo vendidas por outros revendedores?**

# %%
# full dataset
aux = df3.loc[:,['seller_type','name']].groupby('seller_type').count()
aux
# Out:
#              name
# seller_type
# dealer          6
# individual   1055

# %% [markdown]
# **10. Qual é a média de valores das motos na base de dados?**

# %%
# full dataset 
media = df3['selling_price'].mean()
print('A média de preço das motos disponíveis na base de dados é de R${:,.2f}'.format(media))

# without outliers
media = df3_clean['selling_price'].mean()
print('A média de preço das motos disponíveis na base de dados, removendo outliers, é de R${:,.2f}'.format(media))
# Out:
# A média de preço das motos disponíveis na base de dados é de R$59,638.15
# A média de preço das motos disponíveis na base de dados, removendo outliers, é de R$58,365.86

# %% [markdown]
# **11. Qual é a média de ano das motos cadastradas dentro da base de dados?**

# %%
media_ano = np.round(df3['year'].mean())
print('A média de ano das motos da base de dados é de {:.0f}'.format(media_ano))
# Out:
# A média de ano das motos da base de dados é de 2014

# %% [markdown]
# **12. Qual é a média de quilometragem das motos cadastradas dentro da base de dados?**

# %%
# full dataset
media_km = df3['km_driven'].mean()
print('A média de quilometragem das motos da base de dados é de {:,.2f}'.format(media_km))

# without outliers
media_km = df3_clean['km_driven'].mean()
print('A média de quilometragem das motos da base de dados, removendo outliers, é de {:,.2f}'.format(media_km))
# Out:
# A média de quilometragem das motos da base de dados é de 34,359.83
# A média de quilometragem das motos da base de dados, removendo outliers, é de 33,611.52

# %% [markdown]
# **13. Existem quantas motos dentro da base de dados que são motos de um único dono?**

# %%
aux = df3.loc[:,['owner','name']].groupby('owner').count().reset_index()
aux1 = df3_clean.loc[:,['owner','name']].groupby('owner').count().reset_index()

# merge ds with and without outliers
aux2 = pd.merge(aux, aux1, how= 'left', on='owner')

#rename coluns name
aux2.rename(columns= {'name_x': 'qty_full_ds', 'name_y': 'qty_w/o_outliers'}, inplace= True)
aux2
# Out:
#   owner  qty_full_ds  qty_w/o_outliers
# 0  1st           924               923
# 1  2nd           123               122
# 2  3rd            11                11
# 3  4th             3                 2

# %% [markdown]
# **14. As motos com menor quilometragem são as motos mais baratas do Dataset?**

# %%
aux1 = df3_clean.loc[:,['km_driven','selling_price']].groupby('km_driven').mean().reset_index()


ax = sns.scatterplot(data = aux1, x = 'km_driven',  y = 'selling_price',  size = 'selling_price')

ax.set(
    title = 'Preço x Quilometragem',
    xlabel = 'Quilometragem',
    ylabel = 'Preço');

# %% [markdown]
# ## 3.2 Segunda rodada de perguntas

# %%
df32 = df3.copy()
df32_clean = df3_clean.copy()

# %% [markdown]
# **1. As motos que possuiram somente 1 dono são as motos mais caras na média que as motos que tiveram mais donos?**

# %%
# podemos ver que a linha do ID 311 está distorcendo a média de preços das moto que tiverem 4 donos.
# optamos por remover essa linha do dataset para termos dados mais consistentes 
df32.loc[ df32['owner'] == '4th ', : ]
# Out:
#       id                        name  selling_price  year seller_type owner  km_driven  ex_showroom_price in_showroom          company
# 311  311  Harley-Davidson Street 750       330000.0  2014  individual  4th        6500           534000.0           1  Harley-Davidson
# 642  642          TVS Apache RTR 160        15000.0  2009  individual  4th      880000                0.0           0              TVS
# 698  698              Hero Honda CBZ        10000.0  2000  individual  4th       48000                0.0           0            Honda

# %%
# agrupamento - com a linha 311 removida
aux = df32.loc[df32['id'] != 311 , :]
aux2 = np.round(aux[['owner', 'selling_price']].groupby('owner').mean().reset_index(),2)
aux2
# Out:
#   owner  selling_price
# 0  1st        60022.81
# 1  2nd        55666.66
# 2  3rd        55727.27
# 3  4th        12500.00

# %%
ax=sns.barplot(x='owner',y='selling_price', data=aux2 )
plt.xticks(rotation=45)

ax.bar_label(ax.containers[0])

ax.set(
    title= 'Média de preço por quantidade de donos',
    xlabel= 'Donos',
    ylabel= 'Preço');

# %% [markdown]
# **2. As motos que possuiram mais donos são as motos que possuem quilometragem média maior que as motos que possuiram menos donos?**

# %%
aux = df2[['owner', 'km_driven']].groupby('owner').mean().sort_values('km_driven', ascending=False).reset_index()

# %%
ax=sns.barplot(x='owner',y='km_driven', data=aux)
plt.xticks(rotation=45)

ax.bar_label(ax.containers[0])

ax.set(
    title= 'Média de qiulêmtros por quantidade de donos',
    xlabel= 'Donos',
    ylabel= 'Quilometragem média');

# %% [markdown]
# **3. As motos que possuiram mais donos são as motos mais velhas na média?**

# %%
aux = np.round(df2[['owner', 'year']].groupby('owner').mean().sort_values('year', ascending=False).reset_index())

# %%
ax=sns.barplot(x='owner',y='year', data=aux)
plt.xticks(rotation=45)
ax.bar_label(ax.containers[0])
plt.ylim(2000,2025)

ax.set(
    title= 'Media de ano das motos por quantidade de donos',
    xlabel= 'Donos',
    ylabel= 'Ano');

# %% [markdown]
# **4. As motos que são vendidas por revendedores são as motos mais caras na média do que as motos vendidas pelos seus donos?**

# %%
aux = df2[['seller_type', 'selling_price']].groupby('seller_type').mean().sort_values('selling_price', ascending=False).reset_index()

# %%
ax=sns.barplot(x='seller_type',y='selling_price', data=aux)
plt.xticks(rotation=0)
ax.bar_label(ax.containers[0])
plt.ylim(0,80000)

ax.set(
    title= 'Média de preço de acordo com o tipo de vendedor',
    xlabel= 'Tipo de vendedor',
    ylabel= 'Média de preço');

# %% [markdown]
# **5. O CEO lhe entregou um novo dataset chamado companies.csv, onde estão todas as fabricantes de motocicletas. Adicione uma coluna no DataFrame com o nome de company. Essa coluna deve possuir o nome do fabricante de cada moto do DataFrame.**

# %%
#import of new dataset 
df_companies = pd.read_csv('../fund_prog_project/data/csv/companies.csv', index_col=0)

# %%
companies_list = df_companies.values.tolist()
flat_list = []
for xs in companies_list:
    for x in xs:
        flat_list.append(x)

# %%
# setando marca hero honda
df32['company'] = df32['name'].apply(lambda x:'Hero Honda' if x.split()[1] == 'Honda' else  1 ) # funciona

#separando motos da marca hero honda em outro dataset
df_aux = df32.loc[ df32['company'] == "Hero Honda", :]
df_aux2 = df32[df32['company'] != "Hero Honda"]

# # setando as marcas das demais motos
for i in flat_list: df_aux2['company'] = np.where(df_aux2['name'].str.contains(i),i, df_aux2['company'] ) # funciona
    
# # merge dos 2 data sets 

df_r = pd.concat([df_aux2, df_aux])

df_r.drop('in_showroom', inplace=True, axis=1)

# # # Converting Activa to Honda
# # df32['company'] = np.where(df32['company'].str.startswith('Activa'),'Honda', df32['company'] )
# Out:
# /tmp/ipykernel_5913/1954197421.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for i in flat_list: df_aux2['company'] = np.where(df_aux2['name'].str.contains(i),i, df_aux2['company'] ) # funciona

# %%
df_r[df_result['name'] == 'Hero Honda CD Deluxe']
# Out:
#       id                  name  selling_price  year seller_type owner  km_driven  ex_showroom_price     company
# 85    85  Hero Honda CD Deluxe        25000.0  2009  individual  1st       50000                0.0  Hero Honda
# 431  431  Hero Honda CD Deluxe        14700.0  2005  individual  2nd       30000                0.0  Hero Honda
# 472  472  Hero Honda CD Deluxe        24700.0  2012  individual  2nd       40000                0.0  Hero Honda
# 525  525  Hero Honda CD Deluxe        25000.0  2010  individual  1st       35000                0.0  Hero Honda
# 535  535  Hero Honda CD Deluxe        12000.0  2007  individual  2nd      100000                0.0  Hero Honda
# 539  539  Hero Honda CD Deluxe        15000.0  2011  individual  1st       70000                0.0  Hero Honda
# 796  796  Hero Honda CD Deluxe        25000.0  2008  individual  3rd       65000                0.0  Hero Honda
# 932  932  Hero Honda CD Deluxe        25500.0  2012  individual  1st       28990                0.0  Hero Honda
# 934  934  Hero Honda CD Deluxe        20000.0  2005  individual  1st       15000                0.0  Hero Honda

# %% [markdown]
# **6. Crie um novo dataset chamado bikes_completed.csv a partir do DataFrame com a coluna company preenchida.**

# %%
# criação do CSV
df_r.to_csv('data/bikes_completed.csv',index=False)

# teste de criação...
df4 = pd.read_csv('data/bikes_completed.csv')

# %% [markdown]
# **7. Quais são so fabricantes que mais possuem motos cadastradas na base de dados completa?**

# %%
aux = df4[['company', 'id']].groupby('company').count().sort_values('id', ascending=False).reset_index()

ax=sns.barplot(x='company', y='id', data=aux)

plt.xticks(rotation=45)

ax.bar_label(ax.containers[0])

ax.set(
    title= 'Número de motos por Fabricante',
    xlabel= 'Fabricante',
    ylabel= 'Contagem');

# %% [markdown]
# #  4.0 TERCEIRA RODADA DE PERGUNTAS

# %% [markdown]
# **1. Ajustar a coluna `name` para que ela fique somente com o nome da moto.**

# %%
df4.head()
# Out:
#    id                                 name  selling_price  year seller_type owner  km_driven  ex_showroom_price        company
# 0   0            Royal Enfield Classic 350       175000.0  2019  individual  1st         350                0.0  Royal Enfield
# 1   1                            Honda Dio        45000.0  2017  individual  1st        5650                0.0          Honda
# 2   2  Royal Enfield Classic Gunmetal Grey       150000.0  2018  individual  1st       12000           148114.0  Royal Enfield
# 3   3    Yamaha Fazer FI V 2.0 [2016-2018]        65000.0  2015  individual  1st       23000            89643.0         Yamaha
# 4   4                Yamaha SZ [2013-2014]        20000.0  2011  individual  2nd       21000                0.0         Yamaha

# %%
# deixando somente o nome da moto, e ano do modelo da moto no campo name
for i in range( len( df4 )):
    df4.loc[i,'name'] = df4.loc[i,'name'].strip(df4.loc[i,'company'])
 
    
df4['year_model'] = df4['name'].str.split('[', expand=True)[1]
df4['year_model'] = df4['year_model'].str.replace(']','')

for i in range( len( df4 )):
    df4.loc[i,'name'] = df4.loc[i,'name'].split(r'[\[]')[0]
# Out:
# /tmp/ipykernel_5913/1751518704.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df4['year_model'] = df4['year_model'].str.replace(']','')

# %%
df4.fillna("",inplace=True)

# %%
df4[df4['company']== "Hero Honda"]
# Out:
#         id                   name  selling_price  year seller_type owner  km_driven  ex_showroom_price     company year_model
# 973      8             CBZ extrem        30000.0  2010  individual  1st       32000                0.0  Hero Honda
# 974     16                 Glamou        25000.0  2006  individual  1st       27000                0.0  Hero Honda
# 975     29           Splendor NXG        21000.0  2009  individual  1st       10000                0.0  Hero Honda
# 976     38     Passion PRO [2012]        30000.0  2011  individual  1st       42000                0.0  Hero Honda       2012
# 977     55           Passion Plus        25000.0  2006  individual  1st       75000                0.0  Hero Honda
# 978     76     Karizma ZMR [2010]        50000.0  2010  individual  1st       48000                0.0  Hero Honda       2010
# 979     85               CD Delux        25000.0  2009  individual  1st       50000                0.0  Hero Honda
# 980    113                 Glamou        30000.0  2008  individual  1st        7500                0.0  Hero Honda
# 981    115           Passion Plus         7500.0  2004  individual  1st      120000                0.0  Hero Honda
# 982    126             CBZ extrem        25000.0  2010  individual  1st       40000                0.0  Hero Honda
# 983    135             CBZ extrem        20000.0  2007  individual  1st       90000                0.0  Hero Honda
# 984    166                 Pleasu        23000.0  2010  individual  1st       32000                0.0  Hero Honda
# 985    196                    unk        56000.0  2015  individual  1st       48000                0.0  Hero Honda
# 986    197                    unk        58000.0  2015  individual  1st       48000                0.0  Hero Honda
# 987    219                 Glamou        15000.0  2006  individual  1st       80000                0.0  Hero Honda
# 988    225                  Passi         9000.0  2002  individual  2nd       66191                0.0  Hero Honda
# 989    256          Splendor Plus        15000.0  2005  individual  1st       65000                0.0  Hero Honda
# 990    258     Passion PRO [2012]        25000.0  2011  individual  1st       20000                0.0  Hero Honda       2012
# 991    264          Splendor Plus        20000.0  2006  individual  1st       23000                0.0  Hero Honda
# 992    283             CBZ extrem        42000.0  2010  individual  1st       51000                0.0  Hero Honda
# 993    307          Splendor Plus        15000.0  2007  individual  1st       30000                0.0  Hero Honda
# 994    314                    unk        28000.0  2009  individual  1st       40000                0.0  Hero Honda
# 995    321           Splendor PRO        30000.0  2012  individual  1st       22866                0.0  Hero Honda
# 996    333          Splendor Plus        12000.0  2005  individual  1st       48000                0.0  Hero Honda
# 997    346          Splendor Plus        18000.0  2010  individual  1st       35700                0.0  Hero Honda
# 998    349          Splendor Plus        15000.0  2004  individual  1st       14500                0.0  Hero Honda
# 999    363                CD100SS        10000.0  1997  individual  1st      646000                0.0  Hero Honda
# 1000   410          Splendor Plus        28000.0  2008  individual  1st       70889                0.0  Hero Honda
# 1001   422                    Spl        10000.0  2000  individual  1st       61000                0.0  Hero Honda
# 1002   428     Karizma ZMR [2010]        45000.0  2012  individual  3rd       44000                0.0  Hero Honda       2010
# 1003   431               CD Delux        14700.0  2005  individual  2nd       30000                0.0  Hero Honda
# 1004   435                 Glamou        19000.0  2012  individual  1st       32000                0.0  Hero Honda
# 1005   440          Splendor Plus        40000.0  2007  individual  1st       40000                0.0  Hero Honda
# 1006   472               CD Delux        24700.0  2012  individual  2nd       40000                0.0  Hero Honda
# 1007   474     Passion PRO [2012]        12000.0  2012  individual  1st       90000                0.0  Hero Honda       2012
# 1008   478                  CD100        15000.0  1999      dealer  2nd       10000                0.0  Hero Honda
# 1009   482           Passion Plus        40000.0  2018  individual  1st       29000                0.0  Hero Honda
# 1010   485                  CD100        15000.0  2000  individual  1st       50000                0.0  Hero Honda
# 1011   521                 Pleasu        25000.0  2009  individual  1st       50000                0.0  Hero Honda
# 1012   525               CD Delux        25000.0  2010  individual  1st       35000                0.0  Hero Honda
# 1013   530     Passion PRO [2012]        28000.0  2011  individual  2nd       60000                0.0  Hero Honda       2012
# 1014   535               CD Delux        12000.0  2007  individual  2nd      100000                0.0  Hero Honda
# 1015   539               CD Delux        15000.0  2011  individual  1st       70000                0.0  Hero Honda
# 1016   560           Passion Plus        18000.0  2007  individual  2nd       50000                0.0  Hero Honda
# 1017   561     Passion PRO [2012]        28700.0  2012  individual  2nd       49876                0.0  Hero Honda       2012
# 1018   564                 Glamou        21000.0  2010  individual  1st       11000                0.0  Hero Honda
# 1019   568           Passion Plus        23500.0  2010  individual  1st       60000                0.0  Hero Honda
# 1020   571                  CD100        15000.0  1998  individual  1st       65000                0.0  Hero Honda
# 1021   574                 Achiev        15000.0  2009  individual  1st       86000                0.0  Hero Honda
# 1022   575                 Karizm        40000.0  2011  individual  2nd      340000                0.0  Hero Honda
# 1023   599           Street Smart        10000.0  2000  individual  1st       24000                0.0  Hero Honda
# 1024   610          Splendor Plus        15000.0  2006  individual  1st      100000                0.0  Hero Honda
# 1025   612          Splendor Plus        17600.0  2006  individual  1st       52000                0.0  Hero Honda
# 1026   630          Splendor Plus        10000.0  2007  individual  1st       98000                0.0  Hero Honda
# 1027   634           Passion Plus        20000.0  2006  individual  1st       28000                0.0  Hero Honda
# 1028   638  Super Splendor [2005]        20000.0  2008  individual  1st       54000                0.0  Hero Honda       2005
# 1029   648                    Spl        25000.0  2008  individual  1st       38000                0.0  Hero Honda
# 1030   659                 Glamou        35000.0  2012  individual  1st       30000                0.0  Hero Honda
# 1031   660             CBZ extrem        35000.0  2011  individual  1st       35000                0.0  Hero Honda
# 1032   698                    CBZ        10000.0  2000  individual  4th       48000                0.0  Hero Honda
# 1033   710     Passion PRO [2012]        25000.0  2012  individual  2nd       20000                0.0  Hero Honda       2012
# 1034   758           Passion Plus         8000.0  2003  individual  1st       53500                0.0  Hero Honda
# 1035   762          Splendor Plus        20000.0  2006  individual  1st       75000                0.0  Hero Honda
# 1036   766           Splendor NXG        28000.0  2012  individual  1st       49999                0.0  Hero Honda
# 1037   778          Splendor Plus        20000.0  2005  individual  1st       27370                0.0  Hero Honda
# 1038   790           Passion Plus        25000.0  2007  individual  1st       70000                0.0  Hero Honda
# 1039   795                    Spl        10000.0  2006  individual  1st       75000                0.0  Hero Honda
# 1040   796               CD Delux        25000.0  2008  individual  3rd       65000                0.0  Hero Honda
# 1041   807             CBZ extrem        35000.0  2011  individual  1st       28000                0.0  Hero Honda
# 1042   822                 Glamou        45000.0  2012  individual  1st       75000                0.0  Hero Honda
# 1043   853             CBZ extrem        25000.0  2007  individual  1st       80000                0.0  Hero Honda
# 1044   862           Passion Plus        22000.0  2008  individual  2nd       85000                0.0  Hero Honda
# 1045   863          Splendor Plus        15000.0  2007  individual  1st       70000                0.0  Hero Honda
# 1046   901           Passion Plus        25000.0  2008      dealer  2nd      100000                0.0  Hero Honda
# 1047   903          Splendor Plus        20000.0  2004  individual  2nd      127000                0.0  Hero Honda
# 1048   905          Splendor Plus        20000.0  2010  individual  2nd       30000                0.0  Hero Honda
# 1049   920                    unk        45000.0  2013  individual  1st       40000                0.0  Hero Honda
# 1050   925          Splendor Plus        25000.0  2012  individual  1st       70000                0.0  Hero Honda
# 1051   932               CD Delux        25500.0  2012  individual  1st       28990                0.0  Hero Honda
# 1052   933                    unk        35000.0  2010  individual  1st       13000                0.0  Hero Honda
# 1053   934               CD Delux        20000.0  2005  individual  1st       15000                0.0  Hero Honda
# 1054   939             CBZ extrem        30000.0  2011  individual  3rd       70000                0.0  Hero Honda
# 1055   945                    unk        40000.0  2010  individual  1st       41000                0.0  Hero Honda
# 1056   952                    unk        20000.0  2010  individual  1st       17000                0.0  Hero Honda
# 1057   958             CBZ extrem        40000.0  2009  individual  1st       50000                0.0  Hero Honda
# 1058   959             CBZ extrem        35000.0  2012  individual  1st       60000                0.0  Hero Honda
# 1059  1035             CBZ extrem        38000.0  2013  individual  1st       75000            78700.0  Hero Honda
# 1060  1040              Passion P        30000.0  2014  individual  1st       60000            51000.0  Hero Honda

# %%
df4.head(10)
# Out:
#    id                 name  selling_price  year seller_type owner  km_driven  ex_showroom_price        company year_model
# 0   0          Classic 350       175000.0  2019  individual  1st         350                0.0  Royal Enfield
# 1   1                   Di        45000.0  2017  individual  1st        5650                0.0          Honda
# 2   2  Classic Gunmetal Gr       150000.0  2018  individual  1st       12000           148114.0  Royal Enfield
# 3   3      Fazer FI V 2.0         65000.0  2015  individual  1st       23000            89643.0         Yamaha  2016-2018
# 4   4                  SZ         20000.0  2011  individual  2nd       21000                0.0         Yamaha  2013-2014
# 5   5           CB Twister        18000.0  2010  individual  1st       60000            53857.0          Honda
# 6   6       CB Hornet 160R        78500.0  2018  individual  1st       17000            87719.0          Honda
# 7   7          Bullet 350        180000.0  2008  individual  2nd       39000                0.0  Royal Enfield  2007-2011
# 8   9         Discover 125        50000.0  2016  individual  1st       42000            60122.0          Bajaj
# 9  10                 FZ16        35000.0  2015  individual  1st       32000            78712.0         Yamaha

# %%
1. Ajustar a coluna `name` para que ela fique somente com o nome da moto.
2. Qual das fabricantes possui o maior preço médio de suas motos?
3. Qual o fabricante que possui a moto com o maior quilometragem?
4. Qual o fabricante que possui a moto mais velha?
5. O fabricante que possui a moto mais cara do Dataset é também o fabricante que possui menos motos cadastradas?
6. Qual o fabricante que possui a menor variação de valor de venda?
7. Quais motos eu devo comprar? 
   - Leve em conta que eu desejo motos com no máximo 3 anos de uso; no máximo 40 mil quilometros rodados; que sejam de um único dono; que estejam sendo vendidas por possoas físicas e que tenham o valor pretendido de venda menor que o valor do showroom. Envie um relatório contendo o modelo, preço de venda, quilometro rodado e ano, ordenado por valor de venda de forma decrescente para o meu e-mail.
# Out:
#   Input In [960]
#     1. Ajustar a coluna `name` para que ela fique somente com o nome da moto.
#        ^
# SyntaxError: invalid syntax
